# %%
# %pip install googletrans==3.1.0a0

# %%
lt=["A duty well performed creates a corresponding right.-Gandhi",
    " However good a Constitution may be, if those who are implementing it are not good, it will prove to be bad. However, bad a Constitution may be, if those implementing it are good, it will prove to be good- BR Ambedkar ",
    "So long as you do not achieve social justice, whatever freedom is provided by the law to you will be of no avail-BR Ambedkar",
    "By common endeavor we can raise the country to a new greatness, while a lack of unity will expose us to fresh calamities-Sardar Vallabhai Patel",
    "Non-violence has to be observed in thought, word and deed. The measure of our non-violence will be the measure of our success-Sardar Vallabhai Patel",
    "One individual may die for an idea but that idea will after his death incarnate itself in a thousand lives-SC Bose",
    "Every nation has a message to deliver, a mission to fulfill, a destiny to reach. The mission of India has been to guide humanity-Swami Vivekananda",
    "We want deeper sincerity of motive, a greater courage in speech and earnestness in action-Sarojini Naidu",
    "As a young citizen of India, armed with technology and love for my nation, I realize, a small aim is a crime- APJ Abdul Kalam",
    "A duty religiously performed carries with it several other important consequences-Gandhi",
    "A man can give up a right, but he may not give up a duty without being guilty of a grave dereliction-Gandhi",
    "A nation’s culture resides in the hearts and in the souls of its people.-Gandhi"]

# %%
from googletrans import Translator
converted_ml=[]
for i in lt:
    trans=Translator(service_urls=['translate.googleapis.com'])/
    target=trans.translate(i,dest="ml")
    converted_ml.append(target.text)

# %%
#converted_ta,converted_mr,converted_hi,
converted_ml,
# converted_te
# Out:
# (['നന്നായി നിർവഹിക്കുന്ന ഒരു കർത്തവ്യം അതിനനുസൃതമായ അവകാശം സൃഷ്ടിക്കുന്നു.-ഗാന്ധി',
#   'ഭരണഘടന എത്ര നല്ലതാണെങ്കിലും അത് നടപ്പിലാക്കുന്നവർ നല്ലവരല്ലെങ്കിൽ അത് മോശമാണെന്ന് തെളിയും. എന്നിരുന്നാലും, ഒരു ഭരണഘടന മോശമായിരിക്കാം, അത് നടപ്പിലാക്കുന്നവർ നല്ലവരാണെങ്കിൽ അത് നല്ലതാണെന്ന് തെളിയിക്കും - ബി ആർ അംബേദ്കർ',
#   'നിങ്ങൾ സാമൂഹ്യനീതി കൈവരിക്കാത്തിടത്തോളം കാലം നിങ്ങൾക്ക് നിയമം നൽകുന്ന സ്വാതന്ത്ര്യമൊന്നും പ്രയോജനപ്പെടില്ല-ബിആർ അംബേദ്കർ',
#   'പൊതുവായ പരിശ്രമത്തിലൂടെ നമുക്ക് രാജ്യത്തെ ഒരു പുതിയ മഹത്വത്തിലേക്ക് ഉയർത്താൻ കഴിയും, അതേസമയം ഐക്യമില്ലായ്മ നമ്മെ പുതിയ വിപത്തുകളിലേക്ക് നയിക്കും - സർദാർ വല്ലഭായ് പട്ടേൽ',
#   'ചിന്തയിലും വാക്കിലും പ്രവൃത്തിയിലും അഹിംസ പാലിക്കേണ്ടതുണ്ട്. നമ്മുടെ അഹിംസയുടെ അളവുകോലായിരിക്കും നമ്മുടെ വിജയത്തിൻ്റെ അളവുകോൽ-സർദാർ വല്ലഭായ് പട്ടേൽ',
#   'ഒരു വ്യക്തി ഒരു ആശയത്തിനായി മരിക്കാം, എന്നാൽ ആ ആശയം അവൻ്റെ മരണശേഷം ആയിരം ജീവിതങ്ങളിൽ അവതരിക്കും-എസ്\u200cസി ബോസ്',
# ...

# %%
from gtts import gTTS

# %%
# %pip install gtts

# %%
trans=Translator(service_urls=['translate.googleapis.com'])
target=trans.translate(" Money inflation",dest="ta")
tts = gTTS(target.text,lang="ta")
tts.save('processedFile-inflation.mp3')

# %%
target.text
# Out:
# 'பண வீக்கம்'
